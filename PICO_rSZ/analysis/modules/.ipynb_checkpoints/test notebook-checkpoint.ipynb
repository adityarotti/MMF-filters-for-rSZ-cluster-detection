# %%
# %pylab notebook
from spectral_template import sz
from settings import mmf_settings as mmfset
from simulate.spectral_template import planck_band_pass_sz as pbsz
from speimport sz
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
bp=pbsz.band_pass_filtering()

# %%
fn=bp.fn["bb_diffT"]

# %%
fn(np.array(mmfset.channels))
# Out:
# array([  1.33958108e-19,   1.88952250e-19,   2.70172923e-19,
#          3.85112101e-19,   5.41708424e-19,   7.75095628e-19,
#          1.07042227e-18,   1.49757246e-18,   2.02732510e-18,
#          2.74492880e-18,   3.41531358e-18,   4.10791291e-18,
#          4.64576069e-18,   4.82897246e-18,   4.43952033e-18,
#          3.59561523e-18,   2.38730588e-18,   1.29695542e-18,
#          5.15805625e-19,   1.53286529e-19,   2.98104043e-20])

# %%
bp.fn_sz_2d(10.,np.array(mmfset.channels))[:,0]/fn(np.array(mmfset.channels))
# Out:
# array([ -5.20696049,  -5.17806453,  -5.1351409 ,  -5.0738746 ,
#         -4.98936374,  -4.86100698,  -4.69399518,  -4.44182989,
#         -4.10738113,  -3.6007228 ,  -3.03851393,  -2.27635229,
#         -1.2969112 ,   0.09311532,   1.7626635 ,   3.7751705 ,
#          6.74729343,  10.95350598,  18.28031513,  31.82920943,  64.0364007 ])

# %%
plot(mmfset.channels,bp.fn_sz_2d(10.,mmfset.channels)[:,0]/fn(np.array(mmfset.channels)),"o-")
plot(mmfset.channels,bp.fn_sz_2d(50.,mmfset.channels)[:,0]/fn(np.array(mmfset.channels)),"o-")


plot(mmfset.channels,bp.fn_sz_2d(0.,mmfset.channels)[:,0]/fn(np.array(mmfset.channels)),"ko-")
ylim(-10,25)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-10, 25)
