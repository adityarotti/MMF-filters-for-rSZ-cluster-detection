# %%
# %pylab notebook
from modules import parallel_mmf_analysis as pmmf
import time
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from data_preprocess import preprocess_planck_data as ppd
from data_preprocess import get_tangent_planes as gtp
from astropy.io import fits

# %%
ppd.extract_tangent_planes(verbose=True,do_data=True,do_mask=True)

# %%
filename=pmmf.mmf_cat["FILENAME"][0]
print filename
# Out:
# /Users/adityarotti/Documents/Work/Projects/Relativistic-SZ/MMF-filters-for-rSZ-cluster-detection/Planck_MMF//data/tangent_planes/planck/10deg_patches/cluster_G000.04+45.13.fits

# %%
data=gtp.return_data(filename)

# %%
data1=fits.getdata("../../../mmf3/data/tangent_planes/planck/10deg_patches/cluster_G000.04+45.13.fits")

# %%
pmmf.mmfset.conv_KCMB2MJY[545]
# Out:
# 58.0356

# %%
figure()
imshow(data[4,])
colorbar()

figure()
imshow(data1[4,])
colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
pmmf.run_mmf(29)
# Out:
# 29 10.353 8.73933690159 8.74814010518
# 8.739336901593564

# %%
# start=time.time()
# pmmf.run_mmf_in_parallel(8)
# print time.time()-start

# %%
start=time.time()
pmmf.run_mmf_in_parallel(8)
print time.time()-start
# Out:
# 14 14.0864 13.8110896521 13.882995424
# 0 6.75319 7.60341169451 7.58285925114
# 28 7.46826 8.35524989504 8.35473344826
# 98 6.86334 9.21232463691 9.24909808783
# 84 9.32113 8.67717657073 8.68016374938
# 70 10.6513 30.1651861386 30.9537175073
# 42 8.27208 7.49778668307 7.49782458651
# 56 6.34905 5.7170930306 5.69785850412
# 15 7.29635 10.3528305381 10.3050398708
# 29 10.353 9.36251555295 9.34107880397
# 1 9.25669 8.09778623912 8.10410159042
# 99 8.68015 9.00100301996 9.00496249786
# 85 8.57915 7.56273922173 7.5630823755
# 71 7.99745 8.26211365679 8.263491699
# 57 7.78817 7.78138475151 7.7524062595
# 43 6.6217 5.5150144528 5.53620785777
# 16 6.09351 6.83190097636 6.79174615564
# 30 18.32 20.4428007682 20.4490758802
# 100 7.29452 8.72456018869 8.71657793591
# 2 8.57995 9.65874330049 9.67764792286
# 58 13.4922 14.2046735678 14.2344537777
# 86 8.71285 9.25815257293 9.2755535686
# 44 8.87802 8.10088743515 8.14790252649
# 72 6.5406 7.60072554348 7.62523002185
# ...
