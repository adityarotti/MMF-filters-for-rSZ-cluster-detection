# %%
from modules.settings import mmf_settings as mmfset
from data_preprocess import preprocess_planck_data as ppd
from flat_sky_codes import tangent_plane_analysis as tpa
import healpy as h
from astropy.io import fits
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mmfset.channels
# Out:
# array([ 100.,  143.,  217.,  353.,  545.,  857.])

# %%
mmfset.init()

# %%
mask=ppd.gen_ps_mask()
ext_mask=ppd.gen_ps_mask(ps_cutoff=5)

# %%
mmf3=ppd.get_mmf3_catalogue(snrthr=6,cosmo_flag=True,zknown=True)
for idx,clstrname in enumerate(mmf3["NAME"][:2]):
    glon=mmf3["GLON"][idx]
    glat=mmf3["GLAT"][idx]
    snr=mmf3["SNR"][idx]
    filename=mmfset.paths["tplanes"] + "cluster_" + clstrname[5:] + ".fits"
    projop=tpa.tangent_plane_setup(mmfset.nside,mmfset.xsize,glat,glon,rescale=1.)
    
    timage=projop.get_tangent_plane(mask)
    hdu_mask = fits.ImageHDU()
    hdu_mask.header["EXTNAME"]="Point Source Mask"
    hdu_mask.data=timage
    fits.append(filename,hdu_mask.data,hdu_mask.header)
    
    timage=projop.get_tangent_plane(ext_mask)
    hdu_mask = fits.ImageHDU()
    hdu_mask.header["EXTNAME"]="Extended Point Source Mask"
    hdu_mask.data=timage
    fits.append(filename,hdu_mask.data,hdu_mask.header)

# %%
f=fits.open(filename)

# %%
f.info()
# Out:
# Filename: /Users/adityarotti/Documents/Work/Projects/Relativistic-SZ/MMF-filters-for-rSZ-cluster-detection/Planck_MMF//data/tangent_planes/planck/10deg_patches/cluster_G000.13+78.04.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  Channels      1 ImageHDU         7   (9,)   float64
#   2  Data tangent plane    1 ImageHDU        14   (349, 349, 9)   float64
#   3  PS Mask       1 ImageHDU         8   (349, 349)   float64
#   4  Point Source Mask    1 ImageHDU         8   (349, 349)   float64
#   5  Extended Point Source Mask    1 ImageHDU         8   (349, 349)   float64

# %%
filename
# Out:
# '/Users/adityarotti/Documents/Work/Projects/Relativistic-SZ/MMF-filters-for-rSZ-cluster-detection/Planck_MMF//data/tangent_planes/planck/10deg_patches/cluster_G000.13+78.04.fits'

# %%
filen="../../../mmf3/data/planck_tangent_planes/10deg_patches/cluster_G000.13+78.04.fits"
f1=fits.open(filen)
data1=f1[1].data

# %%
figure()
imshow(data1[0,])
# Out:
# <img src="data:image/png;base64,..." width="640">
