# %%
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
f=open("../../tempdata/COM_CosmoParams_base-plikHM-TTTEEE-lowl-lowE_R3/base/plikHM_TTTEEE_lowl_lowE_lensing/base_plikHM_TTTEEE_lowl_lowE_lensing.paramnames","r")
f.read()
# Out:
# 'omegabh2\t\\Omega_b h^2\nomegach2\t\\Omega_c h^2\ntheta\t100\\theta_{MC}\ntau\t\\tau\nlogA\t{\\rm{ln}}(10^{10} A_s)\nns\tn_s\ncalPlanck\ty_{\\rm cal}\nacib217\tA^{CIB}_{217}\nxi\t\\xi^{tSZ-CIB}\nasz143\tA^{tSZ}_{143}\naps100\tA^{PS}_{100}\naps143\tA^{PS}_{143}\naps143217\tA^{PS}_{143\\times217}\naps217\tA^{PS}_{217}\naksz\tA^{kSZ}\nkgal100\tA^{{\\rm dust}TT}_{100}\nkgal143\tA^{{\\rm dust}TT}_{143}\nkgal143217\tA^{{\\rm dust}TT}_{143\\times217}\nkgal217\tA^{{\\rm dust}TT}_{217}\ngalfTE100\tA^{{\\rm dust}TE}_{100}\ngalfTE100143\tA^{{\\rm dust}TE}_{100\\times143}\ngalfTE100217\tA^{{\\rm dust}TE}_{100\\times217}\ngalfTE143\tA^{{\\rm dust}TE}_{143}\ngalfTE143217\tA^{{\\rm dust}TE}_{143\\times217}\ngalfTE217\tA^{{\\rm dust}TE}_{217}\ncal0\tc_{100}\ncal2\tc_{217}\nH0*\tH_0\nomegal*\t\\Omega_\\Lambda\nomegam*\t\\Omega_m\nomegamh2*\t\\Omega_m h^2\nomeganuh2*\t\\Omega_\\nu h^2\nomegamh3*\t\\Omega_m h^3\nsigma8*\t\\sigma_8\nS8*\tS_8\ns8omegamp5*\t\\sigma_8 \\Omega_m^{0.5}\ns8omegamp25*\t\\sigm
# ...

# %%
d=np.loadtxt("../../tempdata/COM_CosmoParams_base-plikHM-TTTEEE-lowl-lowE_R3/base/plikHM_TTTEEE_lowl_lowE_lensing/base_plikHM_TTTEEE_lowl_lowE_lensing_1.txt")

# %%
Om = 31
Ol = 30
H0 = 29
ns = 7
s8 = 36
tau = 5
lnA = 6

# %%
params=[Om, Ol, H0, ns, s8, tau, lnA]

# %%
cov=np.zeros((len(params),len(params)),dtype=np.float64)
for i,p1 in enumerate(params):
    for j,p2 in enumerate(params):
        cov[i,j]=np.mean((d[:,p1]-np.mean(d[:,p1]))*(d[:,p2]-np.mean(d[:,p2])))

# %%
figure()
imshow(cov,origin="lower")
# Out:
# <img src="data:image/png;base64,..." width="640">
