# %%
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d1=np.random.normal(scale=10,size=10000)
d2=np.random.normal(scale=10,size=10000)

# %%
figure()
hist(d1,bins=50,histtype="step",normed=True)
hist((d1-d2)/sqrt(2),bins=50,histtype="step",normed=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([  2.11040625e-04,   2.81387500e-04,   2.81387500e-04,
#           3.51734375e-04,   5.62775001e-04,   7.73815626e-04,
#           9.84856251e-04,   1.40693750e-03,   2.81387500e-03,
#           3.51734375e-03,   4.92428126e-03,   6.47191251e-03,
#           9.70786876e-03,   1.08334188e-02,   1.30845188e-02,
#           1.69535969e-02,   1.83605344e-02,   2.36365500e-02,
#           2.45510594e-02,   2.90532594e-02,   3.36961532e-02,
#           3.48217032e-02,   3.72134969e-02,   4.21377782e-02,
#           3.98163313e-02,   4.02384126e-02,   3.80576594e-02,
#           3.72134969e-02,   3.62989876e-02,   3.41182344e-02,
#           2.92643000e-02,   2.53248750e-02,   2.16668375e-02,
#           1.79384532e-02,   1.47728438e-02,   1.30845188e-02,
#           9.84856251e-03,   8.51197189e-03,   5.90913751e-03,
#           3.79873126e-03,   3.09526250e-03,   2.39179375e-03,
# ...
