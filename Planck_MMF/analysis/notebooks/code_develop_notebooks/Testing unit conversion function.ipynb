# %%
#from modules.
from settings import mmf_settings as mmfset
from data_preprocess import unit_conv as uc
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
uc.conv_KTRJ_KTBB(np.array(mmfset.channels))
# Out:
# array([  1.28650837e+00,   1.65333860e+00,   2.99024294e+00,
#          1.28954797e+01,   1.59549537e+02,   1.56791179e+04])

# %%
x=sorted(mmfset.conv_KRJ_KCMB.values())

# %%
plot(mmfset.channels,x[3:])
plot(mmfset.channels,uc.conv_KTRJ_KTBB(np.array(mmfset.channels)),"--")
loglog()
# Out:
# <img src="data:image/png;base64,..." width="640">
# []
