# %%
import healpy as h

# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d=np.random.normal(5,1,100000)

figure()
hist(d)


figure()
hist(np.log(d)-log(5),histtype="step",bins=50)

# %%
ymap=h.read_map("../../../../../../Data/Lambda_sim/tSZ_skymap_healpix_Nside1024.fits")
ymap=h.ud_grade(ymap,512)

logymap=log10(ymap)
# Out:
# NSIDE = 1024
# ORDERING = RING in fits file
# INDXSCHM = IMPLICIT

# %%
figure()
hist(ymap/1e-6,bins=50,range=[1e-1,5])

# figure()
hist(logymap/(-6),bins=50)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (array([1.60000e+01, 2.40000e+01, 4.00000e+01, 2.40000e+01, 2.40000e+01,
#         4.80000e+01, 5.60000e+01, 9.60000e+01, 5.60000e+01, 1.76000e+02,
#         1.92000e+02, 2.72000e+02, 2.16000e+02, 3.60000e+02, 4.72000e+02,
#         5.60000e+02, 7.44000e+02, 9.92000e+02, 1.33600e+03, 1.50400e+03,
#         1.61600e+03, 2.00800e+03, 2.99200e+03, 3.50400e+03, 4.42400e+03,
#         5.85600e+03, 7.38400e+03, 9.84000e+03, 1.32000e+04, 1.73840e+04,
#         2.30000e+04, 3.06560e+04, 4.14560e+04, 5.65600e+04, 7.87040e+04,
#         1.08600e+05, 1.49040e+05, 2.04200e+05, 2.66320e+05, 3.32856e+05,
#         3.88048e+05, 4.11000e+05, 3.73864e+05, 2.90640e+05, 1.82168e+05,
#         8.98960e+04, 3.29760e+04, 8.72000e+03, 1.40800e+03, 2.00000e+02]),
#  array([0.72290108, 0.72944945, 0.73599781, 0.74254618, 0.74909454,
#         0.75564291, 0.76219128, 0.76873964, 0.77528801, 0.78183637,
# ...

# %%
h.mollview(log(d))
# Out:
# <img src="data:image/png;base64,..." width="849.9999815767466">
