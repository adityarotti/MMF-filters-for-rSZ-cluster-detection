# %%
from modules.settings import mmf_settings as mmfset
from data_preprocess import preprocess_planck_data as ppd
from data_preprocess import get_tangent_planes as gtp
from flat_sky_codes import tangent_plane_analysis as tpa
import healpy as h
from astropy.io import fits
from simulate.spectral_template import planck_band_pass_sz as plbpsz
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
gtp.return_data

# %%
mmfset.channels
# Out:
# array([ 100.,  143.,  217.,  353.,  545.,  857.])

# %%
mmfset.init()

# %%
mmfcat=ppd.extract_tangent_planes(verbose=True,snrthr=15)
# Out:
# Catalogue size:  38
# Working on extraction tangent planes from 30.0 GHz maps
# Working on extraction tangent planes from 44.0 GHz maps
# Working on extraction tangent planes from 70.0 GHz maps
# Working on extraction tangent planes from 100.0 GHz maps
# /Users/adityarotti/Library/Enthought/Canopy/edm/envs/User/lib/python2.7/site-packages/healpy/fitsfunc.py:326: UserWarning: No INDXSCHM keyword in header file : assume IMPLICIT
#   "assume {}".format(schm))
# Working on extraction tangent planes from 143.0 GHz maps
# Working on extraction tangent planes from 217.0 GHz maps
# Working on extraction tangent planes from 353.0 GHz maps
# Working on extraction tangent planes from 545.0 GHz maps
# Working on extraction tangent planes from 857.0 GHz maps
# Appending point source masks
# 30.0 0.0
# 44.0 0.0
# 70.0 0.0
# 100.0 0.00357986603049
# 143.0 0.00269416418651
# 217.0 0.00185663859345
# 353.0 0.00180105061161
# 545.0 0.0017936388807
# 857.0 0.00171581570613
# ...

# %%
catname="cluster_G349.46-59.95.fits"

# %%
filen="../../../mmf3/data/planck_tangent_planes/10deg_patches/" + catname
f1=fits.open(filen)
data1=f1[1].data

# %%
filen="../data/tangent_planes/planck/10deg_patches/" + catname
f2=fits.open(filen)
data2,ch=gtp.return_data(filen)
mask=gtp.return_ps_mask(filen)
emask=gtp.return_ext_ps_mask(filen)
#data2=f2[2].data
#psmask=f2[3].data
#epsmask=f2[4].data

# %%
figure()
imshow(data1[5,]-data2[5,])
colorbar()

# figure()
# imshow()
# colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data2
# Out:
# (array([[[  1.38765245e-04,   8.57648411e-05,   5.20465874e-05, ...,
#            -1.30912580e-04,  -1.46158403e-04,  -1.05584470e-04],
#          [  1.11899462e-04,   2.26140528e-05,   1.09896966e-04, ...,
#             1.04398350e-05,  -6.99512093e-05,  -1.38763615e-04],
#          [  1.87844169e-04,   7.41874755e-05,   1.02252619e-04, ...,
#            -1.34244692e-04,  -1.53576897e-04,  -4.92951185e-05],
#          ...,
#          [  5.20869253e-05,  -1.24655332e-06,  -6.60333317e-05, ...,
#            -1.21704375e-07,  -3.56221608e-05,  -6.20947176e-05],
#          [ -6.34782555e-06,   4.14893148e-05,   2.50978683e-05, ...,
#            -1.55396719e-05,  -4.11639012e-05,  -1.00771795e-04],
#          [ -7.83157739e-05,   6.02605724e-06,   3.07490227e-05, ...,
#            -1.01029793e-04,  -5.90025984e-08,   5.89474837e-07]],
#
#         [[  1.06723644e-04,   1.06246574e-04,   3.53411633e-05, ...,
#            -1.01996564e-04,  -9.97672178e-05,  -1.06961415e-04],
# ...

# %%
mask=f2[3].data
emask=f2[4].data

# %%
figure()
imshow(psmask-epsmask)
colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mask=ppd.gen_ps_mask()
emask=ppd.gen_ps_mask(ps_cutoff=5.)
# Out:
# 30.0 0.0
# 44.0 0.0
# 70.0 0.0
# 100.0 0.00357986603049
# 143.0 0.00269416418651
# 217.0 0.00185663859345
# 353.0 0.00180105061161
# 545.0 0.0017936388807
# 857.0 0.00171581570613
# 30.0 0.0
# 44.0 0.0
# 70.0 0.0
# 100.0 0.00596644338416
# 143.0 0.00449027364418
# 217.0 0.00309439765576
# 353.0 0.00300175101936
# 545.0 0.0029893981345
# 857.0 0.00285969284355

# %%
h.mollview(mask-emask)
h.mollview(emask)
# Out:
# <img src="data:image/png;base64,..." width="850">
# <img src="data:image/png;base64,..." width="850">

# %%
mmfset.ps
