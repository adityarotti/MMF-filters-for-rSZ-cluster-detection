# %%
# %pylab notebook
import healpy as h
from modules.settings import mmf_settings as mmfset
from modules.data_preprocess import preprocess_pico_sims as pps
from modules.data_preprocess import unit_conv as uc
from modules.simulate.spectral_template import sz_spec as szspec
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mmfset.fwhm
# Out:
# {21.0: 40.9,
#  25.0: 34.1,
#  30.0: 28.4,
#  36.0: 23.7,
#  43.0: 19.7,
#  52.0: 16.4,
#  62.0: 13.7,
#  75.0: 11.4,
#  90.0: 9.5,
#  110.0: 7.9,
#  130.0: 6.6,
#  155.0: 5.5,
#  185.0: 4.6,
#  225.0: 3.8,
#  270.0: 3.2,
#  320.0: 2.7,
#  385.0: 2.2,
#  460.0: 1.8,
#  555.0: 1.5,
#  665.0: 1.3,
#  800.0: 1.1}

# %%
bank=szspec.return_sz_sed_template_bank(np.array(mmfset.channels),0,50,1)
obank=szspec.return_pbp_sz_sed_template_bank(0,50,1)

# %%
figure()
plot(sorted(bank[30].keys()),np.array(sorted(bank[30].values()))-np.array(sorted(bank[0].values())),"ro-")
#plot(sorted(obank[30].keys()),sorted(obank[30].values()),"o-")
plot(sorted(bank[20].keys()),np.array(sorted(bank[20].values()))-np.array(sorted(bank[0].values())),"go-")
plot(sorted(bank[10].keys()),np.array(sorted(bank[10].values()))-np.array(sorted(bank[0].values())),"bo-")
#plot(sorted(bank[0].keys()),np.array(sorted(bank[0].values()))-np.array(sorted(bank[0].values())),"r-")

axvline(100,linestyle="dashed")
# plot(sorted(bank[50].keys()),sorted(bank[50].values()))
#ylim(-6,30)
#xlim(10,800)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
uc.conv_KTBB_KTRJ(np.array(mmfset.channels))
figure()
plot(np.array(mmfset.channels),uc.conv_uKTRJ_KTBB(np.array(mmfset.channels)))
loglog()
# Out:
# <img src="data:image/png;base64,..." width="640">
# []

# %%
pps.extract_tangent_planes(numplanes=2,dryrun=True)
# Out:
# 21.0 1.01144275276e-06
# 25.0 1.01624792386e-06
# 30.0 1.02346361825e-06
# 36.0 1.03392624202e-06
# 43.0 1.04868013961e-06
# 52.0 1.07182312187e-06
# 62.0 1.10331612351e-06
# 75.0 1.15400157885e-06
# 90.0 1.22753347425e-06
# 110.0 1.35433470463e-06
# 130.0 1.52029490887e-06
# 155.0 1.79685854798e-06
# 185.0 2.26338453307e-06
# 225.0 3.22093550786e-06
# 270.0 5.04502358239e-06
# 320.0 8.74980685531e-06
# 385.0 1.9075903346e-05
# 460.0 5.01259176751e-05
# 555.0 0.000183472768345
# 665.0 0.000886361782806
# 800.0 0.0065960483254
# 21.0 1.01144275276e-06
# 25.0 1.01624792386e-06
# 30.0 1.02346361825e-06
# 36.0 1.03392624202e-06
# 43.0 1.04868013961e-06
# 52.0 1.07182312187e-06
# 62.0 1.10331612351e-06
# 75.0 1.15400157885e-06
# 90.0 1.22753347425e-06
# 110.0 1.35433470463e-06
# 130.0 1.52029490887e-06
# 155.0 1.79685854798e-06
# 185.0 2.26338453307e-06
# 225.0 3.22093550786e-06
# 270.0 5.04502358239e-06
# 320.0 8.74980685531e-06
# 385.0 1.9075903346e-05
# 460.0 5.01259176751e-05
# ...

# %%
90.5/3.5
# Out:
# 25.857142857142858
