# %%
# %pylab notebook
import gen_masks as gm
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mask=gm.return_center_mask(50.)
figure()
imshow(mask)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mask=gm.return_edge_apodized_mask(edge_width=15.,fwhm=20)
figure()
imshow(mask)
# Out:
# <img src="data:image/png;base64,..." width="640">
