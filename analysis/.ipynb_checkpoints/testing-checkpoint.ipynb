# %%
# %pylab notebook
import healpy as h
from modules.settings import mmf_settings as mmfset
from modules.data_preprocess import preprocess_pico_sims as pps
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mmfset.channels=mmfset.channels[:2]

# %%
pps.extract_tangent_planes(numplanes=2,dryrun=True)
# Out:
# /global/cscratch1/sd/raditya/PICO/reduced_data/noise_21GHz.fits
# ../data/tangent_planes/pico_sims/10deg_patches/noise_pico_sim_tplane_0.fits
# ../data/tangent_planes/pico_sims/10deg_patches/noise_pico_sim_tplane_1.fits
# /global/cscratch1/sd/raditya/PICO/reduced_data/noise_25GHz.fits
# ../data/tangent_planes/pico_sims/10deg_patches/noise_pico_sim_tplane_0.fits
# ../data/tangent_planes/pico_sims/10deg_patches/noise_pico_sim_tplane_1.fits
# /global/cscratch1/sd/raditya/PICO/reduced_data/noise_30GHz.fits
# ../data/tangent_planes/pico_sims/10deg_patches/noise_pico_sim_tplane_0.fits
# ../data/tangent_planes/pico_sims/10deg_patches/noise_pico_sim_tplane_1.fits
# /global/cscratch1/sd/raditya/PICO/reduced_data/noise_36GHz.fits
# ../data/tangent_planes/pico_sims/10deg_patches/noise_pico_sim_tplane_0.fits
# ../data/tangent_planes/pico_sims/10deg_patches/noise_pico_sim_tplane_1.fits
# /global/cscratch1/sd/raditya/PICO/reduced_data/noise_43GHz.fits
# ...
